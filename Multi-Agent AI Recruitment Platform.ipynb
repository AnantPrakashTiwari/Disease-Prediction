# %% [markdown]
# <a href="https://colab.research.google.com/github/AnantPrakashTiwari/Disease-Prediction/blob/main/Multi-Agent%20AI%20Recruitment%20Platform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fastapi uvicorn pyngrok python-multipart pypdf google-generativeai langchain langgraph faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.9/343.9 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 33.1 MB/s eta 0:00:00
# ...

# %%
import os

folders = [
    "app",
    "app/api",
    "app/agents",
    "app/services",
    "uploads"
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)

print("Folders Created")
# Out:
# Folders Created

# %%
import os

folders = [
    "app",
    "app/api",
    "app/agents",
    "app/services",
    "uploads"
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)

print("Folders Created")
# Out:
# Folders Created

# %%
# %%writefile app.py

from fastapi import FastAPI

app = FastAPI()

@app.get("/")
def home():
    return {
        "message": "HireGen AI Running"
    }
# Out:
# Writing app.py

# %%
# !pip install pyngrok

# %%
from pyngrok import ngrok

ngrok.set_auth_token("3ERAONKCPlq0SZAPBuocEhzJBGf_6MddRSuUHEdnUmEAM9Jje")

# %%
import threading
import uvicorn

def run():
    uvicorn.run(app="app:app",
                host="0.0.0.0",
                port=8000)

threading.Thread(target=run).start()

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8000)

print(public_url)
# Out:
# NgrokTunnel: "https://enslave-embassy-smudge.ngrok-free.dev" -> "http://localhost:8000"

# %%
# %%writefile app.py

from fastapi import FastAPI, UploadFile, File
import os

app = FastAPI()

UPLOAD_FOLDER = "uploads"
os.makedirs(UPLOAD_FOLDER, exist_ok=True)

@app.get("/")
def home():
    return {"message": "HireGen AI Running"}

@app.post("/upload-resume")
async def upload_resume(file: UploadFile = File(...)):

    file_path = os.path.join(
        UPLOAD_FOLDER,
        file.filename
    )

    with open(file_path, "wb") as f:
        f.write(await file.read())

    return {
        "status": "success",
        "filename": file.filename
    }
# Out:
# Overwriting app.py

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8000)

print(public_url)
# Out:
# NgrokTunnel: "https://enslave-embassy-smudge.ngrok-free.dev" -> "http://localhost:8000"

# %%
# %%writefile app.py

from fastapi import FastAPI, UploadFile, File
import os

app = FastAPI()

UPLOAD_FOLDER = "uploads"
os.makedirs(UPLOAD_FOLDER, exist_ok=True)

@app.get("/")
def home():
    return {"message": "HireGen AI Running"}

@app.post("/upload-resume")
async def upload_resume(file: UploadFile = File(...)):
    path = os.path.join(UPLOAD_FOLDER, file.filename)

    with open(path, "wb") as f:
        f.write(await file.read())

    return {
        "status": "success",
        "filename": file.filename
    }
# Out:
# Overwriting app.py

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8000)

print(public_url)
# Out:
# /usr/lib/python3.12/codeop.py:126: RuntimeWarning: coroutine 'Server.serve' was never awaited
#   codeob = compile(source, filename, symbol, flags, True)
# ...
# NgrokTunnel: "https://enslave-embassy-smudge.ngrok-free.dev" -> "http://localhost:8000"

# %%
# !pip install fastapi uvicorn pyngrok python-multipart pypdf

# %%
# %%writefile app.py

from fastapi import FastAPI, UploadFile, File
import os

app = FastAPI()

UPLOAD_FOLDER = "uploads"
os.makedirs(UPLOAD_FOLDER, exist_ok=True)

@app.get("/")
def home():
    return {"message": "HireGen AI Running"}

@app.post("/upload-resume")
async def upload_resume(file: UploadFile = File(...)):
    path = os.path.join(UPLOAD_FOLDER, file.filename)

    with open(path, "wb") as f:
        f.write(await file.read())

    return {
        "status": "success",
        "filename": file.filename
    }
# Out:
# Overwriting app.py

# %%
from pyngrok import ngrok

ngrok.set_auth_token("YOUR_TOKEN")

# %%
import threading
import uvicorn

def run():
    uvicorn.run(
        "app:app",
        host="0.0.0.0",
        port=8000
    )

threading.Thread(target=run).start()
# Out:
# INFO:     Started server process [3597]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# ERROR:    [Errno 98] error while attempting to bind on address ('0.0.0.0', 8000): address already in use
# INFO:     Waiting for application shutdown.

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8000)

print(public_url)
# Out:
# NgrokTunnel: "https://enslave-embassy-smudge.ngrok-free.dev" -> "http://localhost:8000"

# %%
# !pip install fastapi uvicorn pyngrok python-multipart pypdf

# %%
# %%writefile app.py

from fastapi import FastAPI, UploadFile, File
import os

app = FastAPI()

UPLOAD_FOLDER = "uploads"
os.makedirs(UPLOAD_FOLDER, exist_ok=True)

@app.get("/")
def home():
    return {"message": "HireGen AI Running"}

@app.post("/upload-resume")
async def upload_resume(file: UploadFile = File(...)):
    path = os.path.join(UPLOAD_FOLDER, file.filename)

    with open(path, "wb") as f:
        f.write(await file.read())

    return {
        "status": "success",
        "filename": file.filename
    }
# Out:
# Overwriting app.py

# %%
from pyngrok import ngrok

ngrok.set_auth_token("3ERAONKCPlq0SZAPBuocEhzJBGf_6MddRSuUHEdnUmEAM9Jje")

# %%
import threading
import uvicorn

def run():
    uvicorn.run(
        "app:app",
        host="0.0.0.0",
        port=8000
    )

threading.Thread(target=run).start()

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8000)

print(public_url)
# Out:
# NgrokTunnel: "https://enslave-embassy-smudge.ngrok-free.dev" -> "http://localhost:8000"
